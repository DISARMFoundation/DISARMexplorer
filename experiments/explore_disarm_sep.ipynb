# %% [markdown]
# # Add other AMITT standards to AMITTsite
#
# This code explores the places online that have AMITT standards embedded in them, ready to
#
# * a) grab the ids, fetures etc for each object, so we can push AMITTsite objects to repos using these standards.
# * b) know where and what to send AMITT object updates.

# %%
import json
import pandas as pd
import requests
import glob

# %% [markdown]
# ## Explore AMITT STIX SEP
#
# Explores the AMITT SEP for STIX.  These objects should be the red team techniques.
#
# Takes objects from guthub repository https://github.com/cogsec-collaborative/cti-sep-repository - this should be cloned into directory github_cogseccollab_amitt_cti
#
# (yes, we could have used requests to grab the files directly from the repo, but later).

# %%
datadir = '../../github_cogseccollab_amitt_cti'

glob.glob('{}/amitt/*/*.json'.format(datadir))
# Out:
# ['../../github_cogseccollab_amitt_cti/amitt/identity/identity--fcf30df9-73fd-4d75-92c7-f871a09303e0.json',
#  '../../github_cogseccollab_amitt_cti/amitt/identity/identity--b09ba394-f1de-4555-a5e0-aa19adba1a28.json',
#  '../../github_cogseccollab_amitt_cti/amitt/identity/identity--3d10cc2d-7f32-486e-af1c-3a88ffcf991e.json',
#  '../../github_cogseccollab_amitt_cti/amitt/identity/identity--bd96e085-c94e-4f59-a448-0599210cc7af.json',
#  '../../github_cogseccollab_amitt_cti/amitt/identity/identity--e6d25a9e-a205-4b57-bed4-e953a46d431f.json',
#  '../../github_cogseccollab_amitt_cti/amitt/identity/identity--b8df621b-b001-4fc8-bd97-03eeacaf4ecf.json',
#  '../../github_cogseccollab_amitt_cti/amitt/identity/identity--f051cd1c-84dc-45d5-abae-0507c5d91abd.json',
#  '../../github_cogseccollab_amitt_cti/amitt/identity/identity--5d624c7f-4356-4092-aeee-e4e5cd2ac164.json',
#  '../../github_cogseccollab_amitt_cti/amitt/identity/identity--0c14232e-3d34-4a61-a266-824da667560b.json',
#  '../../github_cogseccollab_amitt_cti/amitt/identity/identity--bff70535-dc51-43a3-8663-a65f6f170fa5.json',
#  '../../github_cogseccollab_amitt_cti/amitt/identity/identity--65aaca07-42b0-44c1-bdaf-1da84667f2fa.json',
#  '../../github_cogseccollab_amitt_cti/amitt/identity/identity--b9a505d4-e876-43d1-b2b3-da51d0cc881c.json',
#  '../../github_cogseccollab_amitt_cti/amitt/identity/identity--088ffedc-7a4e-4266-bcee-ccf33324f248.json',
#  '../../github_cogseccollab_amitt_cti/amitt/identity/identity--e0a22c6c-f45f-4a29-b4c0-7a228e704bb1.json',
#  '../../github_cogseccollab_amitt_cti/amitt/identity/identity--d520b3a9-67de-46c6-a6f1-7605d6de713e.json',
#  '../../github_cogseccollab_amitt_cti/amitt/identity/identity--4af75830-0469-4b68-b86c-091ac1fb0e89.json',
#  '../../github_cogseccollab_amitt_cti/amitt/identity/identity--946c5330-43fe-4124-9f34-bf4a7cadbceb.json',
#  '../../github_cogseccollab_amitt_cti/amitt/identity/identity--e9fcf080-995a-4029-b9ec-c0354295fbb7.json',
#  '../../github_cogseccollab_amitt_cti/amitt/identity/identity--99def3d3-4085-43b8-89c3-990a22d0149a.json',
#  '../../github_cogseccollab_amitt_cti/amitt/identity/identity--00d88ce2-d068-4979-a3ea-7b26a609f518.json',
#  '../../github_cogseccollab_amitt_cti/amitt/campaign/campaign--138ee1cd-754a-4903-bec7-ec4fb19ed09e.json',
#  '../../github_cogseccollab_amitt_cti/amitt/campaign/campaign--75854e5f-1ed7-4a5a-b955-d35d9dc3534b.json',
#  '../../github_cogseccollab_amitt_cti/amitt/campaign/campaign--7496dc37-7dd7-446a-80b7-82b5fca0553b.json',
#  '../../github_cogseccollab_amitt_cti/amitt/campaign/campaign--e2a15a63-4a08-44a2-a292-84f7c7c6b0fb.json',
#  '../../github_cogseccollab_amitt_cti/amitt/campaign/campaign--39662685-b45c-42c4-b4ed-8e157d619a35.json',
#  '../../github_cogseccollab_amitt_cti/amitt/campaign/campaign--0c56aea9-79f2-42d7-b01a-bec2efc7a4b4.json',
#  '../../github_cogseccollab_amitt_cti/amitt/campaign/campaign--8c5789d3-dd05-4027-b2bb-821fbde4d61a.json',
#  '../../github_cogseccollab_amitt_cti/amitt/campaign/campaign--9101554b-ba89-4078-871b-72ceb7e60328.json',
#  '../../github_cogseccollab_amitt_cti/amitt/campaign/campaign--4cdc3790-7200-4ea6-add2-d5e7cf295d8a.json',
#  '../../github_cogseccollab_amitt_cti/amitt/campaign/campaign--f4190158-786c-4e66-a03e-fb51951cb49d.json']

# %%
# Get contents of file that lists all the AMITT objects

f = open(datadir+'/amitt/amitt-attack.json',)
data = json.load(f)
data
# Out:
# {'type': 'bundle',
#  'id': 'bundle--d700c722-48c5-4cdb-a3ac-cc8c0d95c0fe',
#  'spec_version': '2.0',
#  'objects': [{'type': 'x-amitt-tactic',
#    'id': 'x-amitt-tactic--a906aa36-c586-4994-97d3-e1566b559522',
#    'created_by_ref': 'identity--dcb70c08-a4b0-4d2d-8141-b28ca5f0a43a',
#    'created': '2019-12-08T02:27:58.307Z',
#    'modified': '2019-12-08T02:27:58.307Z',
#    'name': 'Strategic Planning',
#    'description': 'Defining the desired end state that is the set of required conditions that defines achievement of all objectives.',
#    'external_references': [{'source_name': 'amitt-attack',
#      'url': 'https://github.com/misinfosecproject/amitt_framework/blob/master/tactics/TA01.md',
#      'external_id': 'TA01'}],
#    'object_marking_refs': ['marking-definition--c32b1522-2b13-4159-8a40-56fd4151016d'],
#    'x_amitt_shortname': 'strategic-planning'},
#   {'type': 'x-amitt-tactic',
#    'id': 'x-amitt-tactic--29de5849-2be8-49e2-aefe-2655f7fcb411',
#    'created_by_ref': 'identity--dcb70c08-a4b0-4d2d-8141-b28ca5f0a43a',
#    'created': '2019-12-08T02:27:58.308Z',
#    'modified': '2019-12-08T02:27:58.308Z',
#    'name': 'Objective Planning',
#    'description': 'Objectives should be clearly defined, measurable, and achievable. Achieving objectives ties execution of tactical tasks to reaching the desired end state. There are four primary considerations:\n- Each desired effect should link directly to one or more objectives\n- The effect should be measurable\n- The objective statement should not specify the way and means of accomplishment\n- The effect should be distinguishable from the objective it supports as a condition for success, not as another objective or task.',
#    'external_references': [{'source_name': 'amitt-attack',
#      'url': 'https://github.com/misinfosecproject/amitt_framework/blob/master/tactics/TA02.md',
#      'external_id': 'TA02'}],
#    'object_marking_refs': ['marking-definition--c32b1522-2b13-4159-8a40-56fd4151016d'],
#    'x_amitt_shortname': 'objective-planning'},
#   {'type': 'x-amitt-tactic',
#    'id': 'x-amitt-tactic--50d1a2e8-e67d-4d6f-8133-95885bd91698',
#    'created_by_ref': 'identity--dcb70c08-a4b0-4d2d-8141-b28ca5f0a43a',
#    'created': '2019-12-08T02:27:58.308Z',
#    'modified': '2019-12-08T02:27:58.308Z',
#    'name': 'Develop People',
#    'description': 'Develop online and offline users and agents, including automated personas',
#    'external_references': [{'source_name': 'amitt-attack',
#      'url': 'https://github.com/misinfosecproject/amitt_framework/blob/master/tactics/TA03.md',
#      'external_id': 'TA03'}],
#    'object_marking_refs': ['marking-definition--c32b1522-2b13-4159-8a40-56fd4151016d'],
#    'x_amitt_shortname': 'develop-people'},
#   {'type': 'x-amitt-tactic',
#    'id': 'x-amitt-tactic--0137e038-54e7-46ca-8284-1a93b641c477',
#    'created_by_ref': 'identity--dcb70c08-a4b0-4d2d-8141-b28ca5f0a43a',
#    'created': '2019-12-08T02:27:58.308Z',
#    'modified': '2019-12-08T02:27:58.308Z',
#    'name': 'Develop Networks',
#    'description': 'Develop online and offline communities and transmission methods and cultivate assets and unwitting agents',
#    'external_references': [{'source_name': 'amitt-attack',
#      'url': 'https://github.com/misinfosecproject/amitt_framework/blob/master/tactics/TA04.md',
#      'external_id': 'TA04'}],
#    'object_marking_refs': ['marking-definition--c32b1522-2b13-4159-8a40-56fd4151016d'],
#    'x_amitt_shortname': 'develop-networks'},
#   {'type': 'x-amitt-tactic',
#    'id': 'x-amitt-tactic--76119182-f57f-4667-91ec-5569adfe4744',
#    'created_by_ref': 'identity--dcb70c08-a4b0-4d2d-8141-b28ca5f0a43a',
#    'created': '2019-12-08T02:27:58.308Z',
#    'modified': '2019-12-08T02:27:58.308Z',
#    'name': 'Microtargeting',
#    'description': 'Target very specific populations of people',
#    'external_references': [{'source_name': 'amitt-attack',
#      'url': 'https://github.com/misinfosecproject/amitt_framework/blob/master/tactics/TA05.md',
#      'external_id': 'TA05'}],
#    'object_marking_refs': ['marking-definition--c32b1522-2b13-4159-8a40-56fd4151016d'],
#    'x_amitt_shortname': 'microtargeting'},
#   {'type': 'x-amitt-tactic',
#    'id': 'x-amitt-tactic--9db8fe23-e5c4-4215-bb7c-e13917d1565b',
#    'created_by_ref': 'identity--dcb70c08-a4b0-4d2d-8141-b28ca5f0a43a',
#    'created': '2019-12-08T02:27:58.309Z',
#    'modified': '2019-12-08T02:27:58.309Z',
#    'name': 'Develop Content',
#    'description': 'Create and acquire content used in incident',
#    'external_references': [{'source_name': 'amitt-attack',
#      'url': 'https://github.com/misinfosecproject/amitt_framework/blob/master/tactics/TA06.md',
#      'external_id': 'TA06'}],
#    'object_marking_refs': ['marking-definition--c32b1522-2b13-4159-8a40-56fd4151016d'],
#    'x_amitt_shortname': 'develop-content'},
#   {'type': 'x-amitt-tactic',
#    'id': 'x-amitt-tactic--f2f69396-eaaa-438c-b944-adcf946d5144',
#    'created_by_ref': 'identity--dcb70c08-a4b0-4d2d-8141-b28ca5f0a43a',
#    'created': '2019-12-08T02:27:58.309Z',
#    'modified': '2019-12-08T02:27:58.309Z',
#    'name': 'Channel Selection',
#    'description': 'Set up specific delivery, amplification and manipulation channels for incident, including channels to attack. Each channel serves as an atomic surface (test bed) location/site for adversary to hide/conceal the work/content that goes into setting up for this channel and/or other specific platforms.  Contributes to building out a connected ecosystem where this channel can operate as part of a whole campaign/incident',
#    'external_references': [{'source_name': 'amitt-attack',
#      'url': 'https://github.com/misinfosecproject/amitt_framework/blob/master/tactics/TA07.md',
#      'external_id': 'TA07'}],
#    'object_marking_refs': ['marking-definition--c32b1522-2b13-4159-8a40-56fd4151016d'],
#    'x_amitt_shortname': 'channel-selection'},
#   {'type': 'x-amitt-tactic',
#    'id': 'x-amitt-tactic--2092c4a7-0ca8-4cf7-b93c-f10751f7c8b4',
#    'created_by_ref': 'identity--dcb70c08-a4b0-4d2d-8141-b28ca5f0a43a',
#    'created': '2019-12-08T02:27:58.309Z',
#    'modified': '2019-12-08T02:27:58.309Z',
#    'name': 'Pump Priming',
#    'description': 'Release content on a targetted small scale, prior to general release, including releasing seed narratives',
#    'external_references': [{'source_name': 'amitt-attack',
#      'url': 'https://github.com/misinfosecproject/amitt_framework/blob/master/tactics/TA08.md',
#      'external_id': 'TA08'}],
#    'object_marking_refs': ['marking-definition--c32b1522-2b13-4159-8a40-56fd4151016d'],
#    'x_amitt_shortname': 'pump-priming'},
#   {'type': 'x-amitt-tactic',
#    'id': 'x-amitt-tactic--cc1197e9-8582-48a0-a61f-be78568b05e3',
#    'created_by_ref': 'identity--dcb70c08-a4b0-4d2d-8141-b28ca5f0a43a',
#    'created': '2019-12-08T02:27:58.309Z',
#    'modified': '2019-12-08T02:27:58.309Z',
#    'name': 'Exposure',
#    'description': 'Release content to general public or push to larger population',
#    'external_references': [{'source_name': 'amitt-attack',
#      'url': 'https://github.com/misinfosecproject/amitt_framework/blob/master/tactics/TA09.md',
#      'external_id': 'TA09'}],
#    'object_marking_refs': ['marking-definition--c32b1522-2b13-4159-8a40-56fd4151016d'],
#    'x_amitt_shortname': 'exposure'},
#   {'type': 'x-amitt-tactic',
#    'id': 'x-amitt-tactic--f37849dd-f03a-453b-b799-8e931ba9ec7a',
#    'created_by_ref': 'identity--dcb70c08-a4b0-4d2d-8141-b28ca5f0a43a',
#    'created': '2019-12-08T02:27:58.310Z',
#    'modified': '2019-12-08T02:27:58.310Z',
#    'name': 'Go Physical',
#    'description': 'Move incident into offline world',
#    'external_references': [{'source_name': 'amitt-attack',
#      'url': 'https://github.com/misinfosecproject/amitt_framework/blob/master/tactics/TA10.md',
#      'external_id': 'TA10'}],
#    'object_marking_refs': ['marking-definition--c32b1522-2b13-4159-8a40-56fd4151016d'],
#    'x_amitt_shortname': 'go-physical'},
#   {'type': 'x-amitt-tactic',
#    'id': 'x-amitt-tactic--1eaf7783-f721-465f-b223-8d8ccc389d81',
#    'created_by_ref': 'identity--dcb70c08-a4b0-4d2d-8141-b28ca5f0a43a',
#    'created': '2019-12-08T02:27:58.310Z',
#    'modified': '2019-12-08T02:27:58.310Z',
#    'name': 'Persistence',
#    'description': "Keep incident 'alive', beyond the incident creators' efforts",
#    'external_references': [{'source_name': 'amitt-attack',
#      'url': 'https://github.com/misinfosecproject/amitt_framework/blob/master/tactics/TA11.md',
#      'external_id': 'TA11'}],
#    'object_marking_refs': ['marking-definition--c32b1522-2b13-4159-8a40-56fd4151016d'],
#    'x_amitt_shortname': 'persistence'},
#   {'type': 'x-amitt-tactic',
#    'id': 'x-amitt-tactic--0b2b06bc-3a60-4fca-89f1-ddd4439db2f7',
#    'created_by_ref': 'identity--dcb70c08-a4b0-4d2d-8141-b28ca5f0a43a',
#    'created': '2019-12-08T02:27:58.310Z',
#    'modified': '2019-12-08T02:27:58.310Z',
#    'name': 'Measure Effectiveness',
#    'description': 'Measure effectiveness of incident, for use in planning future events',
#    'external_references': [{'source_name': 'amitt-attack',
#      'url': 'https://github.com/misinfosecproject/amitt_framework/blob/master/tactics/TA12.md',
#      'external_id': 'TA12'}],
#    'object_marking_refs': ['marking-definition--c32b1522-2b13-4159-8a40-56fd4151016d'],
#    'x_amitt_shortname': 'measure-effectiveness'},
#   {'type': 'attack-pattern',
#    'id': 'attack-pattern--e3510b6b-2b06-4e7a-becc-0504dfd8946d',
#    'created_by_ref': 'identity--dcb70c08-a4b0-4d2d-8141-b28ca5f0a43a',
#    'created': '2019-12-08T02:27:58.310Z',
#    'modified': '2019-12-08T02:27:58.310Z',
#    'name': '5Ds (dismiss, distort, distract, dismay, divide)',
#    'description': 'Nimmo\'s "4Ds of propaganda": dismiss, distort, distract, dismay (MisinfosecWG added divide in 2019). Misinformation promotes an agenda by advancing narratives supportive of that agenda. This is most effective when the advanced narrative pre-dates the revelation of the specific misinformation content. But this is often not possible.',
#    'kill_chain_phases': [{'kill_chain_name': 'amitt-attack',
#      'phase_name': 'strategic-planning'}],
#    'external_references': [{'source_name': 'amitt-attack',
#      'url': 'https://github.com/misinfosecproject/amitt_framework/blob/master/techniques/T0001.md',
#      'external_id': 'T0001'}],
#    'object_marking_refs': ['marking-definition--c32b1522-2b13-4159-8a40-56fd4151016d'],
#    'x_amitt_platforms': ['Advertising',
#     'Audio',
#     'Augmented Reality',
#     'Digital Publication',
#     'Interactive Media',
#     'Mobile',
#     'Physical',
#     'Physical Publication',
#     'Social Media',
#     'Video',
#     'Video Game'],
#    'x_amitt_version': '1.0'},
#   {'type': 'attack-pattern',
#    'id': 'attack-pattern--f9594365-f1f2-4e37-8a1d-98f88910d6c9',
#    'created_by_ref': 'identity--dcb70c08-a4b0-4d2d-8141-b28ca5f0a43a',
#    'created': '2019-12-08T02:27:58.311Z',
#    'modified': '2019-12-08T02:27:58.311Z',
#    'name': 'Facilitate State Propaganda',
#    'description': 'Organize citizens around pro-state messaging. Paid or volunteer groups coordinated to push state propaganda (examples include 2016 Diba Facebook Expedition, coordinated to overcome China’s Great Firewall to flood the Facebook pages of Taiwanese politicians and news agencies with a pro-PRC message).',
#    'kill_chain_phases': [{'kill_chain_name': 'amitt-attack',
#      'phase_name': 'strategic-planning'}],
#    'external_references': [{'source_name': 'amitt-attack',
#      'url': 'https://github.com/misinfosecproject/amitt_framework/blob/master/techniques/T0002.md',
#      'external_id': 'T0002'}],
#    'object_marking_refs': ['marking-definition--c32b1522-2b13-4159-8a40-56fd4151016d'],
#    'x_amitt_platforms': ['Advertising',
#     'Audio',
#     'Augmented Reality',
#     'Digital Publication',
#     'Interactive Media',
#     'Mobile',
#     'Physical',
#     'Physical Publication',
#     'Social Media',
#     'Video',
#     'Video Game'],
#    'x_amitt_version': '1.0'},
#   {'type': 'attack-pattern',
#    'id': 'attack-pattern--4966343d-1626-491a-a8b2-423c2bf7306d',
#    'created_by_ref': 'identity--dcb70c08-a4b0-4d2d-8141-b28ca5f0a43a',
#    'created': '2019-12-08T02:27:58.311Z',
#    'modified': '2019-12-08T02:27:58.311Z',
#    'name': 'Leverage Existing Narratives',
#    'description': 'Use or adapt existing narrative themes, where narratives are the baseline stories of a target audience. Narratives form the bedrock of our worldviews. New information is understood through a process firmly grounded in this bedrock. If new information is not consitent with the prevailing narratives of an audience, it will be ignored. Effective campaigns will frame their misinformation in the context of these narratives. Highly effective campaigns will make extensive use of audience-appropriate archetypes and meta-narratives throughout their content creation and amplifiction practices. Examples include midwesterners are generous, Russia is under attack from outside.',
#    'kill_chain_phases': [{'kill_chain_name': 'amitt-attack',
#      'phase_name': 'strategic-planning'}],
#    'external_references': [{'source_name': 'amitt-attack',
#      'url': 'https://github.com/misinfosecproject/amitt_framework/blob/master/techniques/T0003.md',
#      'external_id': 'T0003'}],
#    'object_marking_refs': ['marking-definition--c32b1522-2b13-4159-8a40-56fd4151016d'],
#    'x_amitt_platforms': ['Advertising',
#     'Audio',
#     'Augmented Reality',
#     'Digital Publication',
#     'Interactive Media',
#     'Mobile',
#     'Physical',
#     'Physical Publication',
#     'Social Media',
#     'Video',
#     'Video Game'],
#    'x_amitt_version': '1.0'},
#   {'type': 'attack-pattern',
#    'id': 'attack-pattern--a7a56973-dbeb-4ce0-8b59-55fab5358135',
#    'created_by_ref': 'identity--dcb70c08-a4b0-4d2d-8141-b28ca5f0a43a',
#    'created': '2019-12-08T02:27:58.311Z',
#    'modified': '2019-12-08T02:27:58.311Z',
#    'name': 'Competing Narratives',
#    'description': 'Advance competing narratives connected to same issue ie: on one hand deny incident while at same time expresses dismiss. MH17 (example) "Russian Foreign Ministry again claimed that “absolutely groundless accusations are put forward against the Russian side, which are aimed at discrediting Russia in the eyes of the international community" (deny); "The Dutch MH17 investigation is biased, anti-Russian and factually inaccurate" (dismiss). \n\nSuppressing or discouraging narratives already spreading requires an alternative. The most simple set of narrative techniques in response would be the construction and promotion of contradictory alternatives centered on denial, deflection, dismissal, counter-charges, excessive standards of proof, bias in prohibition or enforcement, and so on.\n\nThese competing narratives allow loyalists cover, but are less compelling to opponents and fence-sitters than campaigns built around existing narratives or highly explanatory master narratives. Competing narratives, as such, are especially useful in the "firehose of misinformation" approach.',
#    'kill_chain_phases': [{'kill_chain_name': 'amitt-attack',
#      'phase_name': 'strategic-planning'}],
#    'external_references': [{'source_name': 'amitt-attack',
#      'url': 'https://github.com/misinfosecproject/amitt_framework/blob/master/techniques/T0004.md',
#      'external_id': 'T0004'}],
#    'object_marking_refs': ['marking-definition--c32b1522-2b13-4159-8a40-56fd4151016d'],
#    'x_amitt_platforms': ['Advertising',
#     'Audio',
#     'Augmented Reality',
#     'Digital Publication',
#     'Interactive Media',
#     'Mobile',
#     'Physical',
#     'Physical Publication',
#     'Social Media',
#     'Video',
#     'Video Game'],
#    'x_amitt_version': '1.0'},
#   {'type': 'attack-pattern',
#    'id': 'attack-pattern--17ca1c3e-da1e-4aad-a403-68b22f212501',
#    'created_by_ref': 'identity--dcb70c08-a4b0-4d2d-8141-b28ca5f0a43a',
#    'created': '2019-12-08T02:27:58.312Z',
#    'modified': '2019-12-08T02:27:58.312Z',
#    'name': 'Center of Gravity Analysis',
#    'description': 'Recon/research to identify "the source of power that provides moral or physical strength, freedom of action, or will to act." Thus, the center of gravity is usually seen as the "source of strength". Includes demographic and network analysis of communities',
#    'kill_chain_phases': [{'kill_chain_name': 'amitt-attack',
#      'phase_name': 'objective-planning'}],
#    'external_references': [{'source_name': 'amitt-attack',
#      'url': 'https://github.com/misinfosecproject/amitt_framework/blob/master/techniques/T0005.md',
#      'external_id': 'T0005'}],
#    'object_marking_refs': ['marking-definition--c32b1522-2b13-4159-8a40-56fd4151016d'],
#    'x_amitt_platforms': ['Advertising',
#     'Audio',
#     'Augmented Reality',
#     'Digital Publication',
#     'Interactive Media',
#     'Mobile',
#     'Physical',
#     'Physical Publication',
#     'Social Media',
#     'Video',
#     'Video Game'],
#    'x_amitt_version': '1.0'},
#   {'type': 'attack-pattern',
#    'id': 'attack-pattern--99838171-02cf-4baa-b106-57afef3b66f5',
#    'created_by_ref': 'identity--dcb70c08-a4b0-4d2d-8141-b28ca5f0a43a',
#    'created': '2019-12-08T02:27:58.312Z',
#    'modified': '2019-12-08T02:27:58.312Z',
#    'name': 'Create Master Narratives',
#    'description': 'The promotion of beneficial master narratives is perhaps the most effective method for achieving long-term strategic narrative dominance. From a "whole of society" perpective the promotion of the society\'s core master narratives should occupy a central strategic role. From a misinformation campaign / cognitive security perpectve the tactics around master narratives center more precisely on the day-to-day promotion and reinforcement of this messaging. In other words, beneficial, high-coverage master narratives are a central strategic goal and their promotion consitutes an ongoing tactical struggle carried out at a whole-of-society level. \n\nBy way of example, major powers are promoting master narratives such as:\n* "Huawei is detetmined to build trustworthy networks"\n* "Russia is the victim of bullying by NATO powers"\n* "USA is guided by its founding principles of liberty and egalitarianism"\n\nTactically, their promotion covers a broad spectrum of activities both on- and offline.',
#    'kill_chain_phases': [{'kill_chain_name': 'amitt-attack',
#      'phase_name': 'objective-planning'}],
#    'external_references': [{'source_name': 'amitt-attack',
#      'url': 'https://github.com/misinfosecproject/amitt_framework/blob/master/techniques/T0006.md',
#      'external_id': 'T0006'}],
#    'object_marking_refs': ['marking-definition--c32b1522-2b13-4159-8a40-56fd4151016d'],
#    'x_amitt_platforms': ['Advertising',
#     'Audio',
#     'Augmented Reality',
#     'Digital Publication',
#     'Interactive Media',
#     'Mobile',
#     'Physical',
#     'Physical Publication',
#     'Social Media',
#     'Video',
#     'Video Game'],
#    'x_amitt_version': '1.0'},
#   {'type': 'attack-pattern',
#    'id': 'attack-pattern--2af155a0-e968-4d92-af3e-bcbdbf799764',
#    'created_by_ref': 'identity--dcb70c08-a4b0-4d2d-8141-b28ca5f0a43a',
#    'created': '2019-12-08T02:27:58.312Z',
#    'modified': '2019-12-08T02:27:58.312Z',
#    'name': 'Create fake Social Media Profiles / Pages / Groups',
#    'description': 'Create key social engineering assets needed to amplify content, manipulate algorithms, fool public and/or specific incident/campaign targets. \n\nComputational propaganda depends substantially on false perceptions of credibility and acceptance. By creating fake users and groups with a variety of interests and commitments, attackers can ensure that their messages both come from trusted sources and appear more widely adopted than they actually are. \n\nExamples: Ukraine elections (2019) circumvent Facebook’s new safeguards by paying Ukrainian citizens to give a Russian agent access to their personal pages. EU Elections (2019) Avaaz reported more than 500 suspicious pages and groups to Facebook related to the three-month investigation of Facebook disinformation networks in Europe. Mueller report (2016) The IRA was able to reach up to 126 million Americans on Facebook via a mixture of fraudulent accounts, groups, and advertisements, the report says. Twitter accounts it created were portrayed as real American voices by major news outlets. It was even able to hold real-life rallies, mobilizing hundreds of people at a time in major cities like Philadelphia and Miami. ',
#    'kill_chain_phases': [{'kill_chain_name': 'amitt-attack',
#      'phase_name': 'develop-people'}],
#    'external_references': [{'source_name': 'amitt-attack',
#      'url': 'https://github.com/misinfosecproject/amitt_framework/blob/master/techniques/T0007.md',
#      'external_id': 'T0007'}],
#    'object_marking_refs': ['marking-definition--c32b1522-2b13-4159-8a40-56fd4151016d'],
#    'x_amitt_platforms': ['Advertising',
#     'Audio',
#     'Augmented Reality',
#     'Digital Publication',
#     'Interactive Media',
#     'Mobile',
#     'Physical',
#     'Physical Publication',
#     'Social Media',
#     'Video',
#     'Video Game'],
#    'x_amitt_version': '1.0'},
#   {'type': 'attack-pattern',
#    'id': 'attack-pattern--f82970fd-ea96-4da8-999e-eab5188c9120',
#    'created_by_ref': 'identity--dcb70c08-a4b0-4d2d-8141-b28ca5f0a43a',
#    'created': '2019-12-08T02:27:58.313Z',
#    'modified': '2019-12-08T02:27:58.313Z',
#    'name': 'Create fake or imposter news sites',
#    'description': 'Modern computational propaganda makes use of a cadre of imposter news sites spreading globally. These sites, sometimes motivated by concerns other than propaganda--for instance, click-based revenue--often have some superficial markers of authenticity, such as naming and site-design. But many can be quickly exposed with reference to their owenership, reporting history and adverstising details. A prominent case from the 2016 era was the _Denver Guardian_, which purported to be a local newspaper in Colorado and specialized in negative stories about Hillary Clinton.',
#    'kill_chain_phases': [{'kill_chain_name': 'amitt-attack',
#      'phase_name': 'develop-people'}],
#    'external_references': [{'source_name': 'amitt-attack',
#      'url': 'https://github.com/misinfosecproject/amitt_framework/blob/master/techniques/T0008.md',
#      'external_id': 'T0008'}],
#    'object_marking_refs': ['marking-definition--c32b1522-2b13-4159-8a40-56fd4151016d'],
#    'x_amitt_platforms': ['Advertising',
#     'Audio',
#     'Augmented Reality',
#     'Digital Publication',
#     'Interactive Media',
#     'Mobile',
#     'Physical',
#     'Physical Publication',
#     'Social Media',
#     'Video',
#     'Video Game'],
#    'x_amitt_version': '1.0'},
#   {'type': 'attack-pattern',
#    'id': 'attack-pattern--8c922e8a-fb61-4b8b-b3c0-aecbd7edb7dd',
#    'created_by_ref': 'identity--dcb70c08-a4b0-4d2d-8141-b28ca5f0a43a',
#    'created': '2019-12-08T02:27:58.313Z',
#    'modified': '2019-12-08T02:27:58.313Z',
#    'name': 'Create fake experts',
#    'description': 'Stories planted or promoted in computational propaganda operations often make use of experts fabricated from whole cloth, sometimes specifically for the story itself. For example, in the Jade Helm conspiracy theory promoted by SVR in 2015, a pair of experts--one of them naming himself a “Military Intelligence Analyst / Russian Regional CME” and the other a “Geopolitical Strategist, Journalist & Author”--pushed the story heavily on LinkedIn.',
#    'kill_chain_phases': [{'kill_chain_name': 'amitt-attack',
#      'phase_name': 'develop-people'}],
#    'external_references': [{'source_name': 'amitt-attack',
#      'url': 'https://github.com/misinfosecproject/amitt_framework/blob/master/techniques/T0009.md',
#      'external_id': 'T0009'}],
#    'object_marking_refs': ['marking-definition--c32b1522-2b13-4159-8a40-56fd4151016d'],
#    'x_amitt_platforms': ['Advertising',
#     'Audio',
#     'Augmented Reality',
#     'Digital Publication',
#     'Interactive Media',
#     'Mobile',
#     'Physical',
#     'Physical Publication',
#     'Social Media',
#     'Video',
#     'Video Game'],
#    'x_amitt_version': '1.0'},
#   {'type': 'attack-pattern',
#    'id': 'attack-pattern--841be7e7-5f88-4fd1-8f81-54938d62e52b',
#    'created_by_ref': 'identity--dcb70c08-a4b0-4d2d-8141-b28ca5f0a43a',
#    'created': '2019-12-08T02:27:58.313Z',
#    'modified': '2019-12-08T02:27:58.313Z',
#    'name': 'Cultivate ignorant agents',
#    'description': 'Cultivate propagandists for a cause, the goals of which are not fully comprehended, and who are used cynically by the leaders of the cause. Independent actors use social media and specialised web sites to strategically reinforce and spread messages compatible with their own. Their networks are infiltrated and used by state media disinformation organisations to amplify the state’s own disinformation strategies against target populations. Many are traffickers in conspiracy theories or hoaxes, unified by a suspicion of Western governments and mainstream media. Their narratives, which appeal to leftists hostile to globalism and military intervention and nationalists against immigration, are frequently infiltrated and shaped by state-controlled trolls and altered news items from agencies such as RT and Sputnik. Also know as "useful idiots" or "unwitting agents".',
#    'kill_chain_phases': [{'kill_chain_name': 'amitt-attack',
#      'phase_name': 'develop-networks'}],
#    'external_references': [{'source_name': 'amitt-attack',
#      'url': 'https://github.com/misinfosecproject/amitt_framework/blob/master/techniques/T0010.md',
#      'external_id': 'T0010'}],
#    'object_marking_refs': ['marking-definition--c32b1522-2b13-4159-8a40-56fd4151016d'],
#    'x_amitt_platforms': ['Advertising',
#     'Audio',
#     'Augmented Reality',
#     'Digital Publication',
#     'Interactive Media',
#     'Mobile',
#     'Physical',
#     'Physical Publication',
#     'Social Media',
#     'Video',
#     'Video Game'],
#    'x_amitt_version': '1.0'},
#   {'type': 'attack-pattern',
#    'id': 'attack-pattern--3d882173-f473-426b-9f8d-fa9394475c3b',
#    'created_by_ref': 'identity--dcb70c08-a4b0-4d2d-8141-b28ca5f0a43a',
#    'created': '2019-12-08T02:27:58.313Z',
#    'modified': '2019-12-08T02:27:58.313Z',
#    'name': 'Hijack legitimate account',
#    'description': 'Hack or take over legimate accounts to distribute misinformation or damaging content. Examples include Syrian Electronic Army (2013) series of false tweets from a hijacked Associated Press Twitter account claiming that President Barack Obama had been injured in a series of explosions near the White House. The false report caused a temporary plunge of 143 points on the Dow Jones Industrial Average.',
#    'kill_chain_phases': [{'kill_chain_name': 'amitt-attack',
#      'phase_name': 'develop-networks'}],
#    'external_references': [{'source_name': 'amitt-attack',
#      'url': 'https://github.com/misinfosecproject/amitt_framework/blob/master/techniques/T0011.md',
#      'external_id': 'T0011'}],
#    'object_marking_refs': ['marking-definition--c32b1522-2b13-4159-8a40-56fd4151016d'],
#    'x_amitt_platforms': ['Advertising',
#     'Audio',
#     'Augmented Reality',
#     'Digital Publication',
#     'Interactive Media',
#     'Mobile',
#     'Physical',
#     'Physical Publication',
#     'Social Media',
#     'Video',
#     'Video Game'],
#    'x_amitt_version': '1.0'},
#   {'type': 'attack-pattern',
#    'id': 'attack-pattern--ae55192c-81cc-4adb-81b9-b27375c58acc',
#    'created_by_ref': 'identity--dcb70c08-a4b0-4d2d-8141-b28ca5f0a43a',
#    'created': '2019-12-08T02:27:58.314Z',
#    'modified': '2019-12-08T02:27:58.314Z',
#    'name': 'Use concealment',
#    'description': 'Use anonymous social media profiles. Examples include page or group administrators, masked "whois" website directory data, no bylines connected to news article, no masthead connect to news websites. \n\nExample is 2016 @TEN_GOP profile where the actual Tennessee Republican Party tried unsuccessfully for months to get Twitter to shut it down, and 2019 Endless Mayfly is an Iran-aligned network of inauthentic personas and social media accounts that spreads falsehoods and amplifies narratives critical of Saudi Arabia, the United States, and Israel.',
#    'kill_chain_phases': [{'kill_chain_name': 'amitt-attack',
#      'phase_name': 'develop-networks'}],
#    'external_references': [{'source_name': 'amitt-attack',
#      'url': 'https://github.com/misinfosecproject/amitt_framework/blob/master/techniques/T0012.md',
#      'external_id': 'T0012'}],
#    'object_marking_refs': ['marking-definition--c32b1522-2b13-4159-8a40-56fd4151016d'],
#    'x_amitt_platforms': ['Advertising',
#     'Audio',
#     'Augmented Reality',
#     'Digital Publication',
#     'Interactive Media',
#     'Mobile',
#     'Physical',
#     'Physical Publication',
#     'Social Media',
#     'Video',
#     'Video Game'],
#    'x_amitt_version': '1.0'},
#   {'type': 'attack-pattern',
#    'id': 'attack-pattern--c10a54f4-da7f-49c0-96f1-e992e96374ba',
#    'created_by_ref': 'identity--dcb70c08-a4b0-4d2d-8141-b28ca5f0a43a',
#    'created': '2019-12-08T02:27:58.314Z',
#    'modified': '2019-12-08T02:27:58.314Z',
#    'name': 'Create fake websites',
#    'description': 'Create media assets to support fake organizations (e.g. think tank), people (e.g. experts) and/or serve as sites to distribute malware/launch phishing operations.',
#    'kill_chain_phases': [{'kill_chain_name': 'amitt-attack',
#      'phase_name': 'develop-networks'}],
#    'external_references': [{'source_name': 'amitt-attack',
#      'url': 'https://github.com/misinfosecproject/amitt_framework/blob/master/techniques/T0013.md',
#      'external_id': 'T0013'}],
#    'object_marking_refs': ['marking-definition--c32b1522-2b13-4159-8a40-56fd4151016d'],
#    'x_amitt_platforms': ['Advertising',
#     'Audio',
#     'Augmented Reality',
#     'Digital Publication',
#     'Interactive Media',
#     'Mobile',
#     'Physical',
#     'Physical Publication',
#     'Social Media',
#     'Video',
#     'Video Game'],
#    'x_amitt_version': '1.0'},
#   {'type': 'attack-pattern',
#    'id': 'attack-pattern--1aba2935-a5fa-4db1-bde7-632e708bb531',
#    'created_by_ref': 'identity--dcb70c08-a4b0-4d2d-8141-b28ca5f0a43a',
#    'created': '2019-12-08T02:27:58.314Z',
#    'modified': '2019-12-08T02:27:58.314Z',
#    'name': 'Create funding campaigns',
#    'description': 'Generate revenue through online funding campaigns. e.g. Gather data, advance credible persona via Gofundme; Patreon; or via fake website connecting via PayPal or Stripe. (Example 2016) #VaccinateUS Gofundme campaigns to pay for Targetted facebook ads (Larry Cook, targetting Washington State mothers, $1,776 to boost posts over 9 months).',
#    'kill_chain_phases': [{'kill_chain_name': 'amitt-attack',
#      'phase_name': 'develop-networks'}],
#    'external_references': [{'source_name': 'amitt-attack',
#      'url': 'https://github.com/misinfosecproject/amitt_framework/blob/master/techniques/T0014.md',
#      'external_id': 'T0014'}],
#    'object_marking_refs': ['marking-definition--c32b1522-2b13-4159-8a40-56fd4151016d'],
#    'x_amitt_platforms': ['Advertising',
#     'Audio',
#     'Augmented Reality',
#     'Digital Publication',
#     'Interactive Media',
#     'Mobile',
#     'Physical',
#     'Physical Publication',
#     'Social Media',
#     'Video',
#     'Video Game'],
#    'x_amitt_version': '1.0'},
#   {'type': 'attack-pattern',
#    'id': 'attack-pattern--8f84d9a1-b7f4-43bb-92ba-eba1a305f593',
#    'created_by_ref': 'identity--dcb70c08-a4b0-4d2d-8141-b28ca5f0a43a',
#    'created': '2019-12-08T02:27:58.315Z',
#    'modified': '2019-12-08T02:27:58.315Z',
#    'name': 'Create hashtag',
#    'description': 'Many incident-based campaigns will create a hashtag to promote their fabricated event (e.g. #ColumbianChemicals to promote a fake story about a chemical spill in Louisiana). \n\nCreating a hashtag for an incident can have two important effects:\n1. Create a perception of reality around an event. Certainly only "real" events would be discussed in a hashtag. After all, the event has a name!\n2. Publicize the story more widely through trending lists and search behavior \n\nAsset needed to direct/control/manage "conversation" connected to launching new incident/campaign with new hashtag for applicable social media sites ie: Twitter, LinkedIn)',
#    'kill_chain_phases': [{'kill_chain_name': 'amitt-attack',
#      'phase_name': 'develop-networks'}],
#    'external_references': [{'source_name': 'amitt-attack',
#      'url': 'https://github.com/misinfosecproject/amitt_framework/blob/master/techniques/T0015.md',
#      'external_id': 'T0015'}],
#    'object_marking_refs': ['marking-definition--c32b1522-2b13-4159-8a40-56fd4151016d'],
#    'x_amitt_platforms': ['Advertising',
#     'Audio',
#     'Augmented Reality',
#     'Digital Publication',
#     'Interactive Media',
#     'Mobile',
#     'Physical',
#     'Physical Publication',
#     'Social Media',
#     'Video',
#     'Video Game'],
#    'x_amitt_version': '1.0'},
#   {'type': 'attack-pattern',
#    'id': 'attack-pattern--bf14e1f1-78a1-4db6-ad84-725bbf18aaaf',
#    'created_by_ref': 'identity--dcb70c08-a4b0-4d2d-8141-b28ca5f0a43a',
#    'created': '2019-12-08T02:27:58.315Z',
#    'modified': '2019-12-08T02:27:58.315Z',
#    'name': 'Clickbait',
#    'description': 'Create attention grabbing headlines (outrage, doubt, humor) required to drive traffic & engagement. (example 2016) “Pope Francis shocks world, endorses Donald Trump for president.” (example 2016) "FBI director received millions from Clinton Foundation, his brother’s law firm does Clinton’s taxes”. This is a key asset',
#    'kill_chain_phases': [{'kill_chain_name': 'amitt-attack',
#      'phase_name': 'microtargeting'}],
#    'external_references': [{'source_name': 'amitt-attack',
#      'url': 'https://github.com/misinfosecproject/amitt_framework/blob/master/techniques/T0016.md',
#      'external_id': 'T0016'}],
#    'object_marking_refs': ['marking-definition--c32b1522-2b13-4159-8a40-56fd4151016d'],
#    'x_amitt_platforms': ['Advertising',
#     'Audio',
#     'Augmented Reality',
#     'Digital Publication',
#     'Interactive Media',
#     'Mobile',
#     'Physical',
#     'Physical Publication',
#     'Social Media',
#     'Video',
#     'Video Game'],
#    'x_amitt_version': '1.0'},
#   {'type': 'attack-pattern',
#    'id': 'attack-pattern--e9200d6a-d959-481e-9c5d-6323b6f0b9ac',
#    'created_by_ref': 'identity--dcb70c08-a4b0-4d2d-8141-b28ca5f0a43a',
#    'created': '2019-12-08T02:27:58.315Z',
#    'modified': '2019-12-08T02:27:58.315Z',
#    'name': 'Promote online funding',
#    'description': 'Drive traffic/engagement to funding campaign sites; helps provide measurable metrics to assess conversion rates',
#    'kill_chain_phases': [{'kill_chain_name': 'amitt-attack',
#      'phase_name': 'microtargeting'}],
#    'external_references': [{'source_name': 'amitt-attack',
#      'url': 'https://github.com/misinfosecproject/amitt_framework/blob/master/techniques/T0017.md',
#      'external_id': 'T0017'}],
#    'object_marking_refs': ['marking-definition--c32b1522-2b13-4159-8a40-56fd4151016d'],
#    'x_amitt_platforms': ['Advertising',
#     'Audio',
#     'Augmented Reality',
#     'Digital Publication',
#     'Interactive Media',
#     'Mobile',
#     'Physical',
#     'Physical Publication',
#     'Social Media',
#     'Video',
#     'Video Game'],
#    'x_amitt_version': '1.0'},
#   {'type': 'attack-pattern',
#    'id': 'attack-pattern--e3625d60-3bc5-40fd-9366-885392df8e9b',
#    'created_by_ref': 'identity--dcb70c08-a4b0-4d2d-8141-b28ca5f0a43a',
#    'created': '2019-12-08T02:27:58.315Z',
#    'modified': '2019-12-08T02:27:58.315Z',
#    'name': 'Paid targeted ads',
#    'description': 'Create or fund advertisements targeted at specific populations',
#    'kill_chain_phases': [{'kill_chain_name': 'amitt-attack',
#      'phase_name': 'microtargeting'}],
#    'external_references': [{'source_name': 'amitt-attack',
#      'url': 'https://github.com/misinfosecproject/amitt_framework/blob/master/techniques/T0018.md',
#      'external_id': 'T0018'}],
#    'object_marking_refs': ['marking-definition--c32b1522-2b13-4159-8a40-56fd4151016d'],
#    'x_amitt_platforms': ['Advertising',
#     'Audio',
#     'Augmented Reality',
#     'Digital Publication',
#     'Interactive Media',
#     'Mobile',
#     'Physical',
#     'Physical Publication',
#     'Social Media',
#     'Video',
#     'Video Game'],
#    'x_amitt_version': '1.0'},
#   {'type': 'attack-pattern',
#    'id': 'attack-pattern--0ccc6e6a-6848-4ece-99d5-12e4e016e831',
#    'created_by_ref': 'identity--dcb70c08-a4b0-4d2d-8141-b28ca5f0a43a',
#    'created': '2019-12-08T02:27:58.316Z',
#    'modified': '2019-12-08T02:27:58.316Z',
#    'name': 'Generate information pollution',
#    'description': 'Flood social channels; drive traffic/engagement to all assets; create aura/sense/perception of pervasiveness/consensus (for or against or both simultaneously) of an issue or topic. "Nothing is true, but everything is possible." Akin to astroturfing campaign.',
#    'kill_chain_phases': [{'kill_chain_name': 'amitt-attack',
#      'phase_name': 'develop-content'}],
#    'external_references': [{'source_name': 'amitt-attack',
#      'url': 'https://github.com/misinfosecproject/amitt_framework/blob/master/techniques/T0019.md',
#      'external_id': 'T0019'}],
#    'object_marking_refs': ['marking-definition--c32b1522-2b13-4159-8a40-56fd4151016d'],
#    'x_amitt_platforms': ['Advertising',
#     'Audio',
#     'Augmented Reality',
#     'Digital Publication',
#     'Interactive Media',
#     'Mobile',
#     'Physical',
#     'Physical Publication',
#     'Social Media',
#     'Video',
#     'Video Game'],
#    'x_amitt_version': '1.0'},
#   {'type': 'attack-pattern',
#    'id': 'attack-pattern--c0107442-8550-4474-854a-9018fc6a778a',
#    'created_by_ref': 'identity--dcb70c08-a4b0-4d2d-8141-b28ca5f0a43a',
#    'created': '2019-12-08T02:27:58.316Z',
#    'modified': '2019-12-08T02:27:58.316Z',
#    'name': 'Trial content',
#    'description': 'Iteratively test incident performance (messages, content etc), e.g. A/B test headline/content enagagement metrics; website and/or funding campaign conversion rates',
#    'kill_chain_phases': [{'kill_chain_name': 'amitt-attack',
#      'phase_name': 'develop-content'}],
#    'external_references': [{'source_name': 'amitt-attack',
#      'url': 'https://github.com/misinfosecproject/amitt_framework/blob/master/techniques/T0020.md',
#      'external_id': 'T0020'}],
#    'object_marking_refs': ['marking-definition--c32b1522-2b13-4159-8a40-56fd4151016d'],
#    'x_amitt_platforms': ['Advertising',
#     'Audio',
#     'Augmented Reality',
#     'Digital Publication',
#     'Interactive Media',
#     'Mobile',
#     'Physical',
#     'Physical Publication',
#     'Social Media',
#     'Video',
#     'Video Game'],
#    'x_amitt_version': '1.0'},
#   {'type': 'attack-pattern',
#    'id': 'attack-pattern--99d5f10e-7ed8-4e85-87d1-ff4b73d8e9a4',
#    'created_by_ref': 'identity--dcb70c08-a4b0-4d2d-8141-b28ca5f0a43a',
#    'created': '2019-12-08T02:27:58.316Z',
#    'modified': '2019-12-08T02:27:58.316Z',
#    'name': 'Memes',
#    'description': "Memes are one of the most important single artefact types in all of computational propaganda. Memes in this framework denotes the narrow image-based definition. But that naming is no accident, as these items have most of the important properties of Dawkins' original conception as a self-replicating unit of culture. Memes pull together reference and commentary; image and narrative; emotion and message. Memes are a powerful tool and the heart of modern influence campaigns.",
#    'kill_chain_phases': [{'kill_chain_name': 'amitt-attack',
#      'phase_name': 'develop-content'}],
#    'external_references': [{'source_name': 'amitt-attack',
#      'url': 'https://github.com/misinfosecproject/amitt_framework/blob/master/techniques/T0021.md',
#      'external_id': 'T0021'}],
#    'object_marking_refs': ['marking-definition--c32b1522-2b13-4159-8a40-56fd4151016d'],
#    'x_amitt_platforms': ['Advertising',
#     'Audio',
#     'Augmented Reality',
#     'Digital Publication',
#     'Interactive Media',
#     'Mobile',
#     'Physical',
#     'Physical Publication',
#     'Social Media',
#     'Video',
#     'Video Game'],
#    'x_amitt_version': '1.0'},
#   {'type': 'attack-pattern',
#    'id': 'attack-pattern--8ca7d0b8-b2ad-4a7c-8c40-179e483eaa34',
#    'created_by_ref': 'identity--dcb70c08-a4b0-4d2d-8141-b28ca5f0a43a',
#    'created': '2019-12-08T02:27:58.317Z',
#    'modified': '2019-12-08T02:27:58.317Z',
#    'name': 'Conspiracy narratives',
#    'description': '"Conspiracy narratives appeal to the human desire for explanatory order, by invoking the participation of poweful (often sinister) actors in pursuit of their own political goals. These narratives are especially appealing when an audience is low-information, marginalized or otherwise inclined to reject the prevailing explanation. Conspiracy narratives are an important component of the ""firehose of falsehoods"" model.   \n\nExample: QAnon: conspiracy theory is an explanation of an event or situation that invokes a conspiracy by sinister and powerful actors, often political in motivation, when other explanations are more probable "',
#    'kill_chain_phases': [{'kill_chain_name': 'amitt-attack',
#      'phase_name': 'develop-content'}],
#    'external_references': [{'source_name': 'amitt-attack',
#      'url': 'https://github.com/misinfosecproject/amitt_framework/blob/master/techniques/T0022.md',
#      'external_id': 'T0022'}],
#    'object_marking_refs': ['marking-definition--c32b1522-2b13-4159-8a40-56fd4151016d'],
#    'x_amitt_platforms': ['Advertising',
#     'Audio',
#     'Augmented Reality',
#     'Digital Publication',
#     'Interactive Media',
#     'Mobile',
#     'Physical',
#     'Physical Publication',
#     'Social Media',
#     'Video',
#     'Video Game'],
#    'x_amitt_version': '1.0'},
#   {'type': 'attack-pattern',
#    'id': 'attack-pattern--cef1bc5d-a57e-4122-9a34-d1d71fad2297',
#    'created_by_ref': 'identity--dcb70c08-a4b0-4d2d-8141-b28ca5f0a43a',
#    'created': '2019-12-08T02:27:58.317Z',
#    'modified': '2019-12-08T02:27:58.317Z',
#    'name': 'Distort facts',
#    'description': 'Change, twist, or exaggerate existing facts to construct a narrative that differs from reality. Examples: images and ideas can be distorted by being placed in an improper content',
#    'kill_chain_phases': [{'kill_chain_name': 'amitt-attack',
#      'phase_name': 'develop-content'}],
#    'external_references': [{'source_name': 'amitt-attack',
#      'url': 'https://github.com/misinfosecproject/amitt_framework/blob/master/techniques/T0023.md',
#      'external_id': 'T0023'}],
#    'object_marking_refs': ['marking-definition--c32b1522-2b13-4159-8a40-56fd4151016d'],
#    'x_amitt_platforms': ['Advertising',
#     'Audio',
#     'Augmented Reality',
#     'Digital Publication',
#     'Interactive Media',
#     'Mobile',
#     'Physical',
#     'Physical Publication',
#     'Social Media',
#     'Video',
#     'Video Game'],
#    'x_amitt_version': '1.0'},
#   {'type': 'attack-pattern',
#    'id': 'attack-pattern--0b2adbb7-ebff-4259-abcb-57170d735b04',
#    'created_by_ref': 'identity--dcb70c08-a4b0-4d2d-8141-b28ca5f0a43a',
#    'created': '2019-12-08T02:27:58.317Z',
#    'modified': '2019-12-08T02:27:58.317Z',
#    'name': 'Create fake videos and images',
#    'description': 'Create fake videos and/or images by manipulating existing content or generating new content (e.g. deepfakes). Examples include Pelosi video (making her appear drunk) and photoshoped shark on flooded streets of Houston TX.',
#    'kill_chain_phases': [{'kill_chain_name': 'amitt-attack',
#      'phase_name': 'develop-content'}],
#    'external_references': [{'source_name': 'amitt-attack',
#      'url': 'https://github.com/misinfosecproject/amitt_framework/blob/master/techniques/T0024.md',
#      'external_id': 'T0024'}],
#    'object_marking_refs': ['marking-definition--c32b1522-2b13-4159-8a40-56fd4151016d'],
#    'x_amitt_platforms': ['Advertising',
#     'Audio',
#     'Augmented Reality',
#     'Digital Publication',
#     'Interactive Media',
#     'Mobile',
#     'Physical',
#     'Physical Publication',
#     'Social Media',
#     'Video',
#     'Video Game'],
#    'x_amitt_version': '1.0'},
#   {'type': 'attack-pattern',
#    'id': 'attack-pattern--415dc440-4f00-416e-830d-ca285d780807',
#    'created_by_ref': 'identity--dcb70c08-a4b0-4d2d-8141-b28ca5f0a43a',
#    'created': '2019-12-08T02:27:58.317Z',
#    'modified': '2019-12-08T02:27:58.317Z',
#    'name': 'Leak altered documents',
#    'description': 'Obtain documents (eg by theft or leak), then alter and release, possibly among factual documents/sources. \n\nExample (2019) DFRLab report "Secondary Infektion” highlights incident with key asset being a forged “letter” created by the operation to provide ammunition for far-right forces in Europe ahead of the election.',
#    'kill_chain_phases': [{'kill_chain_name': 'amitt-attack',
#      'phase_name': 'develop-content'}],
#    'external_references': [{'source_name': 'amitt-attack',
#      'url': 'https://github.com/misinfosecproject/amitt_framework/blob/master/techniques/T0025.md',
#      'external_id': 'T0025'}],
#    'object_marking_refs': ['marking-definition--c32b1522-2b13-4159-8a40-56fd4151016d'],
#    'x_amitt_platforms': ['Advertising',
#     'Audio',
#     'Augmented Reality',
#     'Digital Publication',
#     'Interactive Media',
#     'Mobile',
#     'Physical',
#     'Physical Publication',
#     'Social Media',
#     'Video',
#     'Video Game'],
#    'x_amitt_version': '1.0'},
#   {'type': 'attack-pattern',
#    'id': 'attack-pattern--68ff61e9-0ad2-417b-bce9-303a45138f1e',
#    'created_by_ref': 'identity--dcb70c08-a4b0-4d2d-8141-b28ca5f0a43a',
#    'created': '2019-12-08T02:27:58.318Z',
#    'modified': '2019-12-08T02:27:58.318Z',
#    'name': 'Create fake research',
#    'description': 'Create fake academic research. Example: fake social science research is often aimed at hot-button social issues such as gender, race and sexuality. Fake science research can target Climate Science debate or pseudoscience like anti-vaxx',
#    'kill_chain_phases': [{'kill_chain_name': 'amitt-attack',
#      'phase_name': 'develop-content'}],
#    'external_references': [{'source_name': 'amitt-attack',
#      'url': 'https://github.com/misinfosecproject/amitt_framework/blob/master/techniques/T0026.md',
#      'external_id': 'T0026'}],
#    'object_marking_refs': ['marking-definition--c32b1522-2b13-4159-8a40-56fd4151016d'],
#    'x_amitt_platforms': ['Advertising',
#     'Audio',
#     'Augmented Reality',
#     'Digital Publication',
#     'Interactive Media',
#     'Mobile',
#     'Physical',
#     'Physical Publication',
#     'Social Media',
#     'Video',
#     'Video Game'],
#    'x_amitt_version': '1.0'},
#   {'type': 'attack-pattern',
#    'id': 'attack-pattern--4c4793e1-87dd-4f39-b82f-1deaf04158ae',
#    'created_by_ref': 'identity--dcb70c08-a4b0-4d2d-8141-b28ca5f0a43a',
#    'created': '2019-12-08T02:27:58.318Z',
#    'modified': '2019-12-08T02:27:58.318Z',
#    'name': 'Adapt existing narratives',
#    'description': 'Adapting existing narratives to current operational goals is the tactical sweet-spot for an effective misinformation campaign. Leveraging existing narratives is not only more effective, it requires substantially less resourcing, as the promotion of new master narratives operates on a much larger scale, both time and scope. Fluid, dynamic & often interchangeable key master narratives can be ("The morally corrupt West") adapted to divisive (LGBT propaganda) or to distort (individuals working as CIA operatives). For Western audiences, different but equally powerful framings are available, such as "USA has a fraught history in race relations, especially in criminal justice areas."',
#    'kill_chain_phases': [{'kill_chain_name': 'amitt-attack',
#      'phase_name': 'develop-content'}],
#    'external_references': [{'source_name': 'amitt-attack',
#      'url': 'https://github.com/misinfosecproject/amitt_framework/blob/master/techniques/T0027.md',
#      'external_id': 'T0027'}],
#    'object_marking_refs': ['marking-definition--c32b1522-2b13-4159-8a40-56fd4151016d'],
#    'x_amitt_platforms': ['Advertising',
#     'Audio',
#     'Augmented Reality',
#     'Digital Publication',
#     'Interactive Media',
#     'Mobile',
#     'Physical',
#     'Physical Publication',
#     'Social Media',
#     'Video',
#     'Video Game'],
#    'x_amitt_version': '1.0'},
#   {'type': 'attack-pattern',
#    'id': 'attack-pattern--918d8510-c6f1-4f99-8e5c-bf61770d453d',
#    'created_by_ref': 'identity--dcb70c08-a4b0-4d2d-8141-b28ca5f0a43a',
#    'created': '2019-12-08T02:27:58.318Z',
#    'modified': '2019-12-08T02:27:58.318Z',
#    'name': 'Create competing narratives',
# ...
#    'target_ref': 'identity--200339dd-63e4-4cf3-ba0c-82257564bbc5'},
#   {'type': 'relationship',
#    'id': 'relationship--0099bb5d-c9cd-4df6-bd2c-068a2103d3a1',
#    'created': '2019-12-08T02:27:58.412Z',
#    'modified': '2019-12-08T02:27:58.412Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--29edcd4a-35be-4ada-8414-3aeabfc43c6b',
#    'target_ref': 'identity--200339dd-63e4-4cf3-ba0c-82257564bbc5'},
#   {'type': 'relationship',
#    'id': 'relationship--f7dc00a9-fc94-4a1c-bf23-17f209ff89c6',
#    'created': '2019-12-08T02:27:58.412Z',
#    'modified': '2019-12-08T02:27:58.412Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--80e566a3-3e8d-4844-b728-34f72d6dc944',
#    'target_ref': 'identity--200339dd-63e4-4cf3-ba0c-82257564bbc5'},
#   {'type': 'relationship',
#    'id': 'relationship--64b2e6e4-80df-4d76-acbc-254ffd67535c',
#    'created': '2019-12-08T02:27:58.413Z',
#    'modified': '2019-12-08T02:27:58.413Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--4a0d52c3-8781-4383-bf41-421dbecc04b2',
#    'target_ref': 'identity--200339dd-63e4-4cf3-ba0c-82257564bbc5'},
#   {'type': 'relationship',
#    'id': 'relationship--c8f40807-b2df-4e5d-b765-fef7e4f02781',
#    'created': '2019-12-08T02:27:58.413Z',
#    'modified': '2019-12-08T02:27:58.413Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--b1246025-4662-4754-a80c-9692b71fb192',
#    'target_ref': 'identity--200339dd-63e4-4cf3-ba0c-82257564bbc5'},
#   {'type': 'relationship',
#    'id': 'relationship--40551c1c-5061-42b1-8ac8-578fa8f19f22',
#    'created': '2019-12-08T02:27:58.413Z',
#    'modified': '2019-12-08T02:27:58.413Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--0a41ef9a-7c04-4c0a-990d-d7f4f2989449',
#    'target_ref': 'identity--200339dd-63e4-4cf3-ba0c-82257564bbc5'},
#   {'type': 'relationship',
#    'id': 'relationship--61afe32b-7309-460e-a814-6e21dd526983',
#    'created': '2019-12-08T02:27:58.413Z',
#    'modified': '2019-12-08T02:27:58.413Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--a66a5196-eaee-48d4-aa96-338fc294b514',
#    'target_ref': 'identity--200339dd-63e4-4cf3-ba0c-82257564bbc5'},
#   {'type': 'relationship',
#    'id': 'relationship--67fbacb7-6c48-4cf3-85ee-a24783b67b5e',
#    'created': '2019-12-08T02:27:58.413Z',
#    'modified': '2019-12-08T02:27:58.413Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--41c31c81-d8ff-4b99-8617-682f6848bd50',
#    'target_ref': 'identity--0aa51d25-d3f6-4c6e-9dcb-5668f7e79fd2'},
#   {'type': 'relationship',
#    'id': 'relationship--fbee4719-e175-4e31-9127-569c998be2ac',
#    'created': '2019-12-08T02:27:58.413Z',
#    'modified': '2019-12-08T02:27:58.413Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--c8eb3460-de1d-475d-aaf1-d49149d2e238',
#    'target_ref': 'identity--0aa51d25-d3f6-4c6e-9dcb-5668f7e79fd2'},
#   {'type': 'relationship',
#    'id': 'relationship--4dea7add-9bec-45b3-9bcf-08b83a356b51',
#    'created': '2019-12-08T02:27:58.414Z',
#    'modified': '2019-12-08T02:27:58.414Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--19f8ca0d-c174-431c-a700-031a2b15b88e',
#    'target_ref': 'identity--1e12546b-6f08-44ca-ae89-7a720aeb350c'},
#   {'type': 'relationship',
#    'id': 'relationship--6c4af880-ba38-4f0e-9730-2afcdd6e6c94',
#    'created': '2019-12-08T02:27:58.414Z',
#    'modified': '2019-12-08T02:27:58.414Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--92e068a6-cd2c-40df-a5ec-6743e1f065d0',
#    'target_ref': 'identity--200339dd-63e4-4cf3-ba0c-82257564bbc5'},
#   {'type': 'relationship',
#    'id': 'relationship--cc7a6989-e105-4aa3-8e97-2e8ba3765ad5',
#    'created': '2019-12-08T02:27:58.414Z',
#    'modified': '2019-12-08T02:27:58.414Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--9dbc6519-6551-499d-8c5e-2177b1b6e30e',
#    'target_ref': 'identity--200339dd-63e4-4cf3-ba0c-82257564bbc5'},
#   {'type': 'relationship',
#    'id': 'relationship--15456870-736d-4e3b-93da-bae998d793ce',
#    'created': '2019-12-08T02:27:58.414Z',
#    'modified': '2019-12-08T02:27:58.414Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--2d60ed11-1b52-4ca8-b195-296737608a06',
#    'target_ref': 'identity--200339dd-63e4-4cf3-ba0c-82257564bbc5'},
#   {'type': 'relationship',
#    'id': 'relationship--eabb1c81-3017-41f3-a5b6-33715cc179cb',
#    'created': '2019-12-08T02:27:58.414Z',
#    'modified': '2019-12-08T02:27:58.414Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--c277a8fe-fc25-4b47-b766-5fc2ac3e298f',
#    'target_ref': 'identity--0aa51d25-d3f6-4c6e-9dcb-5668f7e79fd2'},
#   {'type': 'relationship',
#    'id': 'relationship--5f75eca7-e14b-49af-b589-285b0c322584',
#    'created': '2019-12-08T02:27:58.414Z',
#    'modified': '2019-12-08T02:27:58.414Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--9eeb3f52-c0e1-4b2b-85cd-ee1b6c3fa764',
#    'target_ref': 'identity--200339dd-63e4-4cf3-ba0c-82257564bbc5'},
#   {'type': 'relationship',
#    'id': 'relationship--6ddebb42-a1b8-4e3c-9d0c-1caa4441ada1',
#    'created': '2019-12-08T02:27:58.414Z',
#    'modified': '2019-12-08T02:27:58.414Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--0ae02757-c7f9-4ec0-8fce-a4e72abd8cf0',
#    'target_ref': 'identity--200339dd-63e4-4cf3-ba0c-82257564bbc5'},
#   {'type': 'relationship',
#    'id': 'relationship--8c77d1eb-3e2a-4ab0-ae71-ad8cbffc27dd',
#    'created': '2019-12-08T02:27:58.415Z',
#    'modified': '2019-12-08T02:27:58.415Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--ab312e1b-4894-4b33-9b40-4389ba27a239',
#    'target_ref': 'identity--200339dd-63e4-4cf3-ba0c-82257564bbc5'},
#   {'type': 'relationship',
#    'id': 'relationship--45c83fa8-2d86-46af-9f35-6897ec85e41b',
#    'created': '2019-12-08T02:27:58.415Z',
#    'modified': '2019-12-08T02:27:58.415Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--c487343b-cb3d-4440-af54-8bd5499d5bfc',
#    'target_ref': 'identity--4af75830-0469-4b68-b86c-091ac1fb0e89'},
#   {'type': 'relationship',
#    'id': 'relationship--ffdf6f0c-2dfd-4ae6-a025-c4c291b70bb5',
#    'created': '2019-12-08T02:27:58.415Z',
#    'modified': '2019-12-08T02:27:58.415Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--07884ca2-4e62-49cf-93f2-550e8e690afe',
#    'target_ref': 'identity--200339dd-63e4-4cf3-ba0c-82257564bbc5'},
#   {'type': 'relationship',
#    'id': 'relationship--30cfc249-1698-4618-8aaa-bff8a92079af',
#    'created': '2019-12-08T02:27:58.415Z',
#    'modified': '2019-12-08T02:27:58.415Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--3623995e-44c2-4bb3-9615-4e5de6110d16',
#    'target_ref': 'identity--200339dd-63e4-4cf3-ba0c-82257564bbc5'},
#   {'type': 'relationship',
#    'id': 'relationship--d07ed7c0-adda-429e-8942-d49cba67c3d4',
#    'created': '2019-12-08T02:27:58.415Z',
#    'modified': '2019-12-08T02:27:58.415Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--a06f81bd-d880-42df-aab8-3022f02a4100',
#    'target_ref': 'identity--200339dd-63e4-4cf3-ba0c-82257564bbc5'},
#   {'type': 'relationship',
#    'id': 'relationship--8f355d5c-af80-4829-b33a-91a882050554',
#    'created': '2019-12-08T02:27:58.415Z',
#    'modified': '2019-12-08T02:27:58.415Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--6b7ac915-c526-44e0-9f3f-c741e9d49fb0',
#    'target_ref': 'identity--200339dd-63e4-4cf3-ba0c-82257564bbc5'},
#   {'type': 'relationship',
#    'id': 'relationship--b388064e-7944-4443-8ebc-ca95065f836e',
#    'created': '2019-12-08T02:27:58.416Z',
#    'modified': '2019-12-08T02:27:58.416Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--90de869b-514c-4ba8-b0e9-cf7c9ea956b6',
#    'target_ref': 'identity--200339dd-63e4-4cf3-ba0c-82257564bbc5'},
#   {'type': 'relationship',
#    'id': 'relationship--6063fb96-3c6c-47d8-b0cb-5f2ff48c8d7b',
#    'created': '2019-12-08T02:27:58.416Z',
#    'modified': '2019-12-08T02:27:58.416Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--d174f08d-1a15-49e7-9983-d877bc2f306c',
#    'target_ref': 'identity--200339dd-63e4-4cf3-ba0c-82257564bbc5'},
#   {'type': 'relationship',
#    'id': 'relationship--8e905e3f-9ab8-4c29-aed5-c313ab98650d',
#    'created': '2019-12-08T02:27:58.416Z',
#    'modified': '2019-12-08T02:27:58.416Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--db2f9d6a-8dc9-4fa3-b951-6d632a4b9696',
#    'target_ref': 'identity--200339dd-63e4-4cf3-ba0c-82257564bbc5'},
#   {'type': 'relationship',
#    'id': 'relationship--199b9bc9-56dc-42d2-a1f9-9480533778d8',
#    'created': '2019-12-08T02:27:58.416Z',
#    'modified': '2019-12-08T02:27:58.416Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--ba29d969-a619-4f37-b445-731cd288ca74',
#    'target_ref': 'identity--1e12546b-6f08-44ca-ae89-7a720aeb350c'},
#   {'type': 'relationship',
#    'id': 'relationship--8aa9fc2c-3e8b-48a3-81ef-c11effadfa04',
#    'created': '2019-12-08T02:27:58.416Z',
#    'modified': '2019-12-08T02:27:58.416Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--205612bf-d7db-4a71-894a-babbacd40a41',
#    'target_ref': 'identity--65aaca07-42b0-44c1-bdaf-1da84667f2fa'},
#   {'type': 'relationship',
#    'id': 'relationship--18b78d57-c828-4e64-bac3-8f57d1d754c4',
#    'created': '2019-12-08T02:27:58.416Z',
#    'modified': '2019-12-08T02:27:58.416Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--980dca3a-1384-426a-9a16-9e5b487ac95e',
#    'target_ref': 'identity--65aaca07-42b0-44c1-bdaf-1da84667f2fa'},
#   {'type': 'relationship',
#    'id': 'relationship--4316bc4c-a12d-49e9-ae30-c089977996a2',
#    'created': '2019-12-08T02:27:58.416Z',
#    'modified': '2019-12-08T02:27:58.416Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--84d1fa96-10e8-4eb5-a8fc-97602aa7962a',
#    'target_ref': 'identity--65aaca07-42b0-44c1-bdaf-1da84667f2fa'},
#   {'type': 'relationship',
#    'id': 'relationship--99dadb09-4480-44e3-9c4e-2a5627a4972f',
#    'created': '2019-12-08T02:27:58.417Z',
#    'modified': '2019-12-08T02:27:58.417Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--37198b4b-5ad7-4c89-9624-12e898c4ff0a',
#    'target_ref': 'identity--0aa51d25-d3f6-4c6e-9dcb-5668f7e79fd2'},
#   {'type': 'relationship',
#    'id': 'relationship--d9940d0f-204d-4a9b-a50f-2080043a325c',
#    'created': '2019-12-08T02:27:58.417Z',
#    'modified': '2019-12-08T02:27:58.417Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--93112a32-fec0-4893-a3e9-a5b17db48c30',
#    'target_ref': 'identity--0aa51d25-d3f6-4c6e-9dcb-5668f7e79fd2'},
#   {'type': 'relationship',
#    'id': 'relationship--bda87978-f9ae-44ab-b6b6-ee2ebebc1cc4',
#    'created': '2019-12-08T02:27:58.417Z',
#    'modified': '2019-12-08T02:27:58.417Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--cd458619-4a09-4c99-8866-ff640a1b1cd5',
#    'target_ref': 'identity--0aa51d25-d3f6-4c6e-9dcb-5668f7e79fd2'},
#   {'type': 'relationship',
#    'id': 'relationship--193236e3-40c4-4e8f-b9f1-7818a55f5746',
#    'created': '2019-12-08T02:27:58.417Z',
#    'modified': '2019-12-08T02:27:58.417Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--9e0f379e-ab84-47d2-8930-70aa3f90f936',
#    'target_ref': 'identity--5d624c7f-4356-4092-aeee-e4e5cd2ac164'},
#   {'type': 'relationship',
#    'id': 'relationship--c18fa149-aa85-4352-b983-60333e0ca24c',
#    'created': '2019-12-08T02:27:58.417Z',
#    'modified': '2019-12-08T02:27:58.417Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--8804e1a6-7d50-4099-ba66-abc2605cff80',
#    'target_ref': 'identity--0aa51d25-d3f6-4c6e-9dcb-5668f7e79fd2'},
#   {'type': 'relationship',
#    'id': 'relationship--f7058f6d-c861-4f14-b86a-db3fb6dbdd0e',
#    'created': '2019-12-08T02:27:58.417Z',
#    'modified': '2019-12-08T02:27:58.417Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--49897485-75a8-42c6-b0d4-01e59a6603fe',
#    'target_ref': 'identity--200339dd-63e4-4cf3-ba0c-82257564bbc5'},
#   {'type': 'relationship',
#    'id': 'relationship--37163f81-aa88-4fd8-ad57-03d00aca1db4',
#    'created': '2019-12-08T02:27:58.418Z',
#    'modified': '2019-12-08T02:27:58.418Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--76dfb3fa-edce-4968-989e-8d2bdeee0f1d',
#    'target_ref': 'identity--200339dd-63e4-4cf3-ba0c-82257564bbc5'},
#   {'type': 'relationship',
#    'id': 'relationship--ae1e1f6d-2e51-4df5-b598-88d380e1b9cd',
#    'created': '2019-12-08T02:27:58.418Z',
#    'modified': '2019-12-08T02:27:58.418Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--56cb949f-c085-4520-be35-7129d44227fa',
#    'target_ref': 'identity--200339dd-63e4-4cf3-ba0c-82257564bbc5'},
#   {'type': 'relationship',
#    'id': 'relationship--661eeeac-3218-4c23-931c-43efc1014bf9',
#    'created': '2019-12-08T02:27:58.418Z',
#    'modified': '2019-12-08T02:27:58.418Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--9bed50b9-ef9e-49a3-9ce2-ee28bd58a8df',
#    'target_ref': 'identity--200339dd-63e4-4cf3-ba0c-82257564bbc5'},
#   {'type': 'relationship',
#    'id': 'relationship--091dca15-638a-4594-8864-66b20eeff3fe',
#    'created': '2019-12-08T02:27:58.418Z',
#    'modified': '2019-12-08T02:27:58.418Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--7f884f0f-744b-4f60-b105-6cba08ea5179',
#    'target_ref': 'identity--200339dd-63e4-4cf3-ba0c-82257564bbc5'},
#   {'type': 'relationship',
#    'id': 'relationship--98732144-4b5c-4999-8c94-b29af95a7404',
#    'created': '2019-12-08T02:27:58.418Z',
#    'modified': '2019-12-08T02:27:58.418Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--93c2c356-5387-4bec-9ad7-5ad240484688',
#    'target_ref': 'identity--200339dd-63e4-4cf3-ba0c-82257564bbc5'},
#   {'type': 'relationship',
#    'id': 'relationship--289a3a97-38fd-4b57-8e51-4ba85f7cd9e7',
#    'created': '2019-12-08T02:27:58.418Z',
#    'modified': '2019-12-08T02:27:58.418Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--952842af-dda4-4906-ad87-0404e82576a7',
#    'target_ref': 'identity--200339dd-63e4-4cf3-ba0c-82257564bbc5'},
#   {'type': 'relationship',
#    'id': 'relationship--2e39b439-d3fc-4612-a299-258ade452e1a',
#    'created': '2019-12-08T02:27:58.419Z',
#    'modified': '2019-12-08T02:27:58.419Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--59a14b24-a768-49ec-ac5b-ceb892198fde',
#    'target_ref': 'identity--1e12546b-6f08-44ca-ae89-7a720aeb350c'},
#   {'type': 'relationship',
#    'id': 'relationship--834d5a9c-9b18-4f50-a735-55982b86129d',
#    'created': '2019-12-08T02:27:58.419Z',
#    'modified': '2019-12-08T02:27:58.419Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--1e1794a5-b1fb-4c20-a525-14ea265fb111',
#    'target_ref': 'identity--1e12546b-6f08-44ca-ae89-7a720aeb350c'},
#   {'type': 'relationship',
#    'id': 'relationship--ce23d7e6-7fed-4897-9e8a-f7d45388f465',
#    'created': '2019-12-08T02:27:58.419Z',
#    'modified': '2019-12-08T02:27:58.419Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--22d45770-cafa-49c6-a496-0168cd6682d0',
#    'target_ref': 'identity--200339dd-63e4-4cf3-ba0c-82257564bbc5'},
#   {'type': 'relationship',
#    'id': 'relationship--9b50a885-6609-4408-9598-3042dea855a2',
#    'created': '2019-12-08T02:27:58.419Z',
#    'modified': '2019-12-08T02:27:58.419Z',
#    'relationship_type': 'attributed-to',
#    'source_ref': 'x-opencti-incident--eea22c6e-c3f1-4258-915e-3c1fcfc87678',
#    'target_ref': 'identity--200339dd-63e4-4cf3-ba0c-82257564bbc5'}]}

# %%
# Pull json for all the objects in the repo into one dictionary
objects = {}
for obj in data['objects']:
    summary = obj['type']
    objects[obj['id']] = obj
    if 'name' in obj: 
        summary = '{}: '.format(obj['name']) + summary
    if 'external_references' in obj:
       summary = '{} '.format(obj['external_references'][0]['external_id']) + summary
    if obj['type'] != 'relationship':
        print(summary)

# unfinished - look at standards for relationships between objects        
for obj in data['objects']:
    if obj['type'] == 'relationship':
        continue
# Out:
# TA01 Strategic Planning: x-amitt-tactic
# TA02 Objective Planning: x-amitt-tactic
# TA03 Develop People: x-amitt-tactic
# TA04 Develop Networks: x-amitt-tactic
# TA05 Microtargeting: x-amitt-tactic
# TA06 Develop Content: x-amitt-tactic
# TA07 Channel Selection: x-amitt-tactic
# TA08 Pump Priming: x-amitt-tactic
# TA09 Exposure: x-amitt-tactic
# TA10 Go Physical: x-amitt-tactic
# TA11 Persistence: x-amitt-tactic
# TA12 Measure Effectiveness: x-amitt-tactic
# T0001 5Ds (dismiss, distort, distract, dismay, divide): attack-pattern
# T0002 Facilitate State Propaganda: attack-pattern
# T0003 Leverage Existing Narratives: attack-pattern
# T0004 Competing Narratives: attack-pattern
# T0005 Center of Gravity Analysis: attack-pattern
# T0006 Create Master Narratives: attack-pattern
# T0007 Create fake Social Media Profiles / Pages / Groups: attack-pattern
# T0008 Create fake or imposter news sites: attack-pattern
# T0009 Create fake experts: attack-pattern
# T0010 Cultivate ignorant agents: attack-pattern
# T0011 Hijack legitimate account: attack-pattern
# T0012 Use concealment: attack-pattern
# T0013 Create fake websites: attack-pattern
# T0014 Create funding campaigns: attack-pattern
# T0015 Create hashtag: attack-pattern
# T0016 Clickbait: attack-pattern
# T0017 Promote online funding: attack-pattern
# T0018 Paid targeted ads: attack-pattern
# T0019 Generate information pollution: attack-pattern
# T0020 Trial content: attack-pattern
# T0021 Memes: attack-pattern
# T0022 Conspiracy narratives: attack-pattern
# T0023 Distort facts: attack-pattern
# T0024 Create fake videos and images: attack-pattern
# T0025 Leak altered documents: attack-pattern
# T0026 Create fake research: attack-pattern
# T0027 Adapt existing narratives: attack-pattern
# T0028 Create competing narratives: attack-pattern
# T0029 Manipulate online polls: attack-pattern
# T0030 Backstop personas: attack-pattern
# T0031 YouTube: attack-pattern
# T0032 Reddit: attack-pattern
# T0033 Instagram: attack-pattern
# T0034 LinkedIn: attack-pattern
# T0035 Pinterest: attack-pattern
# T0036 WhatsApp: attack-pattern
# T0037 Facebook: attack-pattern
# T0038 Twitter: attack-pattern
# T0039 Bait legitimate influencers: attack-pattern
# T0040 Demand unsurmountable proof: attack-pattern
# T0041 Deny involvement: attack-pattern
# T0042 Kernel of Truth: attack-pattern
# T0043 Use SMS/ WhatsApp/ Chat apps: attack-pattern
# T0044 Seed distortions: attack-pattern
# T0045 Use fake experts: attack-pattern
# T0046 Search Engine Optimization: attack-pattern
# T0047 Muzzle social media as a political force: attack-pattern
# T0048 Cow online opinion leaders: attack-pattern
# T0049 Flooding: attack-pattern
# T0050 Cheerleading domestic social media ops: attack-pattern
# T0051 Fabricate social media comment: attack-pattern
# T0052 Tertiary sites amplify news: attack-pattern
# T0053 Twitter trolls amplify and manipulate: attack-pattern
# T0054 Twitter bots amplify: attack-pattern
# T0055 Use hashtag: attack-pattern
# T0056 Dedicated channels disseminate information pollution: attack-pattern
# T0057 Organise remote rallies and events: attack-pattern
# T0058 Legacy web content: attack-pattern
# T0059 Play the long game: attack-pattern
# T0060 Continue to amplify: attack-pattern
# T0061 Sell merchandising: attack-pattern
# amitt-attack AMITT Misinformation Framework: x-amitt-matrix
# CNN 2017-09-28 Blacktivists facebook group: x-opencti-incident
# TheGuardian 2018-05-10 Beyonce protest rallies: x-opencti-incident
# Nieman Lab 2018-09 #Macrongate: x-opencti-incident
# Wikipedia: Columbian Chemicals Columbian Chemicals: x-opencti-incident
# Politifact 2016-08-16 Incirlik terrorists: x-opencti-incident
# Stopfake: the virgin hostil operation Bujic: x-opencti-incident
# Codastory: little known pro-kremlin activist PhilippinesExpert: x-opencti-incident
# New York Times 2018-03-27 ParklandTeens: x-opencti-incident
# WCPO: fact check viral misinfo CovingtonTeen: x-opencti-incident
# CJR: memes pollution censorship ChinaSmog: x-opencti-incident
# Medium: trolltracker glimpse FranceBlacktivists: x-opencti-incident
# Wired: co-opting french unrest GiletsJaunePileon: x-opencti-incident
# The Atlantic: new mueller filing ConcordDiscovery: x-opencti-incident
# BuzzFeed: far right trolls are spreading hoaxes MacronTiphaine: x-opencti-incident
# Medium: three thousand fake tanks 3000 tanks: x-opencti-incident
# Medium: hashtag campaign #Macronleaks: x-opencti-incident
# Medium: french twitter mobs in election #dislikemacron: x-opencti-incident
# Medium: altright syriahox to america #syriahoax: x-opencti-incident
# Medium: spread it on reddit EU Army: x-opencti-incident
# Washington Post 2016–04-08 Netherlands referendum on Ukraine: x-opencti-incident
# Helda Helsinki: Khaldarova Pantti Fake News crucifiedboy: x-opencti-incident
# Stopfake: ukrainian boeing tragedy MH17 downed: x-opencti-incident
# Slate: last jedi twitter backlash LastJedi: x-opencti-incident
# AJPH 2018 304567 antivax: x-opencti-incident
# qz.com: trolls and bots are flooding twitter Kavanaugh: x-opencti-incident
# illinois.edu: 96746 DibaFacebookExpedition: x-opencti-incident
# Wilson Center: bots brazil social media elections BrazilPresDebate: x-opencti-incident
# uol.com.br: 2016-10-1823713 Rioelections: x-opencti-incident
# labic.net: a rede das imagens Brazilimpeachment: x-opencti-incident
# BuzzFeed: hyperpartisan sites MerkelFacebook: x-opencti-incident
# New York Times 2017-02-06 modamaniSelfie: x-opencti-incident
# uebermedien.de: 11488 Refugee crime map: x-opencti-incident
# columbia.edu: robot wars battle gulf Saudi/Qatar bot dispute: x-opencti-incident
# Gizmodo: fake fcc comments FCC comments: x-opencti-incident
# Politifact 2018-05-03 JadeHelm exercise: x-opencti-incident
# Bellingcat: skripal Skripal: x-opencti-incident
# New York Times 2018-09-16 North Macedonia: x-opencti-incident
# Sea of Azov: x-opencti-incident
# Atlantic Council: breaking ghouta disinformation 2 White Helmets: Chemical Weapons: x-opencti-incident
# euvsdisinfo.eu: information battlefield venezuela #HandsOffVenezuela: x-opencti-incident
# eaworldview.com: counter russia disinformation Integrity Initiative: x-opencti-incident
# The Atlantic: czech zeman babis China Huawei CFO Arrest: x-opencti-incident
# CTV News: foreign concerns over muslim rights China Muslims: x-opencti-incident
# smh.com.au:misinformation seeded by bots and trolls Mexico Election: x-opencti-incident
# thebureauinvestigates.com 2018-09-04 Chemnitz: x-opencti-incident
# Washington Post 2018-08-23 #VaccinateUS: campaign
# Forbes 2018-11-01 Brexit vote: campaign
# FT c7e6ceb5ffdf LithuanianElves: campaign
# DNI: ICA 2017 01 US presidential elections: campaign
# Medium: fakes bots and blockings Armenia elections: campaign
# Novayagazeta 2015-05-07 MH17 investigation: campaign
# New York Times 2016-05-13 Olympic Doping Scandal: campaign
# oii.ox.ac.uk: comprop brazil Brazilelections: campaign
# TheSyriaCampaign.org: killing the truth White Helmets: campaign
# FireEye: iranian influence operation Iran Influence Operations: campaign
# Reuters: myanmar facebook hate Myanmar - Rohingya : campaign
# smk.com.au: high price of white genocide White Genocide: campaign
# Stripes: fbi investigate bot targeting veterans Military veterans Targetting: campaign
# Politico: britain nationalists Brexit/UK ongoing: campaign
# Internet Research Agency: intrusion-set
# Harvard.edu: chinese government fabricates social media 50cent Army: intrusion-set
# Russia: identity
# China: identity
# France: identity
# Serbia: identity
# World: identity
# Syria: identity
# EU: identity
# Netherlands: identity
# Ukraine: identity
# Taiwan: identity
# Brazil: identity
# Germany: identity
# Qatar: identity
# Saudi Arabia: identity
# UK: identity
# Macedonia: identity
# USA: identity
# Canada: identity
# Lithuania: identity
# Armenia: identity
# Myanmar: identity
# Iran: identity
# Mexico: identity
# Philippines: identity
# Uknown: identity

# %%
# Print out last object
obj
# Out:
# {'type': 'relationship',
#  'id': 'relationship--9b50a885-6609-4408-9598-3042dea855a2',
#  'created': '2019-12-08T02:27:58.419Z',
#  'modified': '2019-12-08T02:27:58.419Z',
#  'relationship_type': 'attributed-to',
#  'source_ref': 'x-opencti-incident--eea22c6e-c3f1-4258-915e-3c1fcfc87678',
#  'target_ref': 'identity--200339dd-63e4-4cf3-ba0c-82257564bbc5'}

# %% [markdown]
# ## Explore AMITT MISP galaxy objects
#
# Explore the AMITT MISP galaxy (this should contain AMITT techniques).
#
# The repo this investigates is the AMITT cluster in https://github.com/MISP/misp-galaxy/

# %%
url = 'https://raw.githubusercontent.com/MISP/misp-galaxy/main/clusters/misinfosec-amitt-misinformation-pattern.json'
r = requests.get(url, allow_redirects=True)
mispjson = r.json()
print('{}'.format(mispjson['values']))
# Out:
# [{'description': 'Nimmo\'s "4Ds of propaganda": dismiss, distort, distract, dismay (MisinfosecWG added divide in 2019). Misinformation promotes an agenda by advancing narratives supportive of that agenda. This is most effective when the advanced narrative pre-dates the revelation of the specific misinformation content. But this is often not possible.', 'meta': {'external_id': 'T0001', 'kill_chain': ['misinformation-tactics:Strategic Planning'], 'refs': ['https://github.com/misinfosecproject/amitt_framework/blob/master/techniques/T0001.md']}, 'uuid': '16556f68-fe4f-43c8-a8a4-6fc205d80251', 'value': '5Ds (dismiss, distort, distract, dismay, divide)'}, {'description': 'Organize citizens around pro-state messaging. Paid or volunteer groups coordinated to push state propaganda (examples include 2016 Diba Facebook Expedition, coordinated to overcome China’s Great Firewall to flood the Facebook pages of Taiwanese politicians and news agencies with a pro-PRC message).', 'meta': {'external_id': 'T0002', 'kill_chain': ['misinformation-tactics:Strategic Planning'], 'refs': ['https://github.com/misinfosecproject/amitt_framework/blob/master/techniques/T0002.md']}, 'uuid': '35f79572-d306-4df1-92e7-84e4d2242baf', 'value': 'Facilitate State Propaganda'}, {'description': 'Use or adapt existing narrative themes, where narratives are the baseline stories of a target audience. Narratives form the bedrock of our worldviews. New information is understood through a process firmly grounded in this bedrock. If new information is not consitent with the prevailing narratives of an audience, it will be ignored. Effective campaigns will frame their misinformation in the context of these narratives. Highly effective campaigns will make extensive use of audience-appropriate archetypes and meta-narratives throughout their content creation and amplifiction practices. Examples include midwesterners are generous, Russia is under attack from outside.', 'meta': {'external_id': 'T0003', 'kill_chain': ['misinformation-tactics:Strategic Planning'], 'refs': ['https://github.com/misinfosecproject/amitt_framework/blob/master/techniques/T0003.md']}, 'uuid': '05f58511-8d22-45d5-b889-47a07b9be00d', 'value': 'Leverage Existing Narratives'}, {'description': 'Advance competing narratives connected to same issue ie: on one hand deny incident while at same time expresses dismiss. MH17 (example) "Russian Foreign Ministry again claimed that “absolutely groundless accusations are put forward against the Russian side, which are aimed at discrediting Russia in the eyes of the international community" (deny); "The Dutch MH17 investigation is biased, anti-Russian and factually inaccurate" (dismiss). \n\nSuppressing or discouraging narratives already spreading requires an alternative. The most simple set of narrative techniques in response would be the construction and promotion of contradictory alternatives centered on denial, deflection, dismissal, counter-charges, excessive standards of proof, bias in prohibition or enforcement, and so on.\n\nThese competing narratives allow loyalists cover, but are less compelling to opponents and fence-sitters than campaigns built around existing narratives or highly explanatory master narratives. Competing narratives, as such, are especially useful in the "firehose of misinformation" approach.', 'meta': {'external_id': 'T0004', 'kill_chain': ['misinformation-tactics:Strategic Planning'], 'refs': ['https://github.com/misinfosecproject/amitt_framework/blob/master/techniques/T0004.md']}, 'uuid': '8960c6c3-ab73-41b3-b661-901f4e4ed5e6', 'value': 'Competing Narratives'}, {'description': 'Recon/research to identify "the source of power that provides moral or physical strength, freedom of action, or will to act." Thus, the center of gravity is usually seen as the "source of strength". Includes demographic and network analysis of communities', 'meta': {'external_id': 'T0005', 'kill_chain': ['misinformation-tactics:Objective Planning'], 'refs': ['https:// ...

# %%
for v in mispjson['values']:
    print('{}: {}'.format(v['meta']['external_id'], v['value']))
# Out:
# T0001: 5Ds (dismiss, distort, distract, dismay, divide)
# T0002: Facilitate State Propaganda
# T0003: Leverage Existing Narratives
# T0004: Competing Narratives
# T0005: Center of Gravity Analysis
# T0006: Create Master Narratives
# T0007: Create fake Social Media Profiles / Pages / Groups
# T0008: Create fake or imposter news sites
# T0009: Create fake experts
# T0010: Cultivate useful idiots
# T0011: Hijack legitimate account
# T0012: Use concealment
# T0013: Create fake websites
# T0014: Create funding campaigns
# T0015: Create hashtag
# T0016: Clickbait
# T0017: Promote online funding
# T0018: Paid targeted ads
# T0019: Generate information pollution
# T0020: Trial content
# T0021: Memes
# T0022: Conspiracy narratives
# T0023: Distort facts
# T0024: Create fake videos and images
# T0025: Leak altered documents
# T0026: Create fake research
# T0027: Adapt existing narratives
# T0028: Create competing narratives
# T0029: Manipulate online polls
# T0030: Backstop personas
# T0031: YouTube
# T0032: Reddit
# T0033: Instagram
# T0034: LinkedIn
# T0035: Pinterest
# T0036: WhatsApp
# T0037: Facebook
# T0038: Twitter
# T0039: Bait legitimate influencers
# T0040: Demand unsurmountable proof
# T0041: Deny involvement
# T0042: Kernel of Truth
# T0043: Use SMS/ WhatsApp/ Chat apps
# T0044: Seed distortions
# T0045: Use fake experts
# T0046: Search Engine Optimization
# T0047: Muzzle social media as a political force
# T0048: Cow online opinion leaders
# T0049: Flooding
# T0050: Cheerleading domestic social media ops
# T0051: Fabricate social media comment
# T0052: Tertiary sites amplify news
# T0053: Twitter trolls amplify and manipulate
# T0054: Twitter bots amplify
# T0055: Use hashtag
# T0056: Dedicated channels disseminate information pollution
# T0057: Organise remote rallies and events
# T0058: Legacy web content
# T0059: Play the long game
# T0060: Continue to amplify
# T0061: Sell merchandising

# %% [markdown]
# # Explore general MISP Objects
#
# This code looks at the new objects CogSecCollab added to MISP last year, and grabs their ids and features so we can push data up to a MISP instance via the MISP API.
#
# Assumes you've cloned the repo https://github.com/MISP/misp-objects.git into folder github_misp_misp-objects
#
# Objects of potential interest are:
# * **Disinfo objects**: narrative,
# * **Social media objects**:  blog, facebook-account, facebook-group, facebook-page, facebook-post, instant-message, instant-message-group, meme-image, microblog, parler-account, parler-comment, parler-post, reddit-account, reddit-comment, reddit-post, reddit-subreddit, short-message-service, social-media-group, telegram-account, twitter-account, twitter-list, twitter-post, user-account, youtube-channel, youtube-comment, youtube-playlist, youtube-video
# * **Documents**: forged-document, image, leaked-document, publication,
# * **General objects**: geolocation, impersonation, news-agency, news-media, organization, person, translation, url, whois,

# %%
mispdir = '../../github_misp_misp-objects'

objectjsons = {}
mispjsonfiles = glob.glob(mispdir + '/objects/*/definition.json')

for mispfile in mispjsonfiles:
    with open(mispfile) as json_file:
        filejson = json.load(json_file)
        objectjsons[filejson['name']] = filejson

print('{}'.format('\n'.join(sorted(set(objectjsons.keys())))))
# Out:
# ail-leak
# ais-info
# android-app
# android-permission
# annotation
# anonymisation
# asn
# attack-pattern
# authentication-failure-report
# authenticode-signerinfo
# av-signature
# bank-account
# bgp-hijack
# bgp-ranking
# blog
# boleto
# btc-transaction
# btc-wallet
# cap-alert
# cap-info
# cap-resource
# coin-address
# command
# command-line
# cookie
# cortex
# cortex-taxonomy
# course-of-action
# covid19-csse-daily-report
# covid19-dxy-live-city
# covid19-dxy-live-province
# cowrie
# cpe-asset
# credential
# credit-card
# crypto-material
# cytomic-orion-file
# cytomic-orion-machine
# dark-pattern-item
# ddos
# device
# diameter-attack
# dkim
# dns-record
# domain-crawled
# domain-ip
# elf
# elf-section
# email
# employee
# exploit-poc
# facebook-account
# facebook-group
# facebook-page
# facebook-post
# facial-composite
# fail2ban
# favicon
# file
# forensic-case
# forensic-evidence
# forged-document
# ftm-Airplane
# ftm-Assessment
# ftm-Asset
# ftm-Associate
# ftm-Audio
# ftm-BankAccount
# ftm-Call
# ftm-Company
# ftm-Contract
# ftm-ContractAward
# ftm-CourtCase
# ftm-CourtCaseParty
# ftm-Debt
# ftm-Directorship
# ftm-Document
# ftm-Documentation
# ftm-EconomicActivity
# ftm-Email
# ftm-Event
# ftm-Family
# ftm-Folder
# ftm-HyperText
# ftm-Image
# ftm-Land
# ftm-LegalEntity
# ftm-License
# ftm-Membership
# ftm-Message
# ftm-Organization
# ftm-Ownership
# ftm-Package
# ftm-Page
# ftm-Pages
# ftm-Passport
# ftm-Payment
# ftm-Person
# ftm-PlainText
# ftm-PublicBody
# ftm-RealEstate
# ftm-Representation
# ftm-Row
# ftm-Sanction
# ftm-Succession
# ftm-Table
# ftm-TaxRoll
# ftm-UnknownLink
# ftm-UserAccount
# ftm-Vehicle
# ftm-Vessel
# ftm-Video
# ftm-Workbook
# geolocation
# git-vuln-finder
# github-user
# gitlab-user
# gtp-attack
# http-request
# ilr-impact
# ilr-notification-incident
# image
# impersonation
# imsi-catcher
# instant-message
# instant-message-group
# intel471-vulnerability-intelligence
# intelmq_event
# intelmq_report
# internal-reference
# interpol-notice
# iot-device
# iot-firmware
# ip-api-address
# ip-port
# irc
# ja3
# jarm
# keybase-account
# leaked-document
# legal-entity
# lnk
# macho
# macho-section
# mactime-timeline-analysis
# malware-config
# meme-image
# microblog
# mutex
# narrative
# netflow
# network-connection
# network-profile
# network-socket
# news-agency
# news-media
# open-data-security
# organization
# original-imported-file
# paloalto-threat-event
# parler-account
# parler-comment
# parler-post
# passive-dns
# passive-dns-dnsdbflex
# paste
# pcap-metadata
# pe
# pe-section
# person
# pgp-meta
# phishing
# phishing-kit
# phone
# process
# publication
# python-etvx-event-log
# r2graphity
# reddit-account
# reddit-comment
# reddit-post
# reddit-subreddit
# regexp
# registry-key
# regripper-NTUser
# regripper-sam-hive-single-user
# regripper-sam-hive-user-group
# regripper-software-hive-BHO
# regripper-software-hive-appInit-DLLS
# regripper-software-hive-application-paths
# regripper-software-hive-applications-installed
# regripper-software-hive-command-shell
# regripper-software-hive-software-run
# regripper-software-hive-userprofile-winlogon
# regripper-software-hive-windows-general-info
# regripper-system-hive-firewall-configuration
# regripper-system-hive-general-configuration
# regripper-system-hive-network-information
# regripper-system-hive-services-drivers
# report
# research-scanner
# rogue-dns
# rtir
# sandbox-report
# sb-signature
# scheduled-event
# scrippsco2-c13-daily
# scrippsco2-c13-monthly
# scrippsco2-co2-daily
# scrippsco2-co2-monthly
# scrippsco2-o18-daily
# scrippsco2-o18-monthly
# script
# shell-commands
# shodan-report
# short-message-service
# shortened-link
# social-media-group
# splunk
# ss7-attack
# ssh-authorized-keys
# stix2-pattern
# suricata
# target-system
# telegram-account
# threatgrid-report
# timecode
# timesketch-timeline
# timesketch_message
# timestamp
# tor-hiddenservice
# tor-node
# tracking-id
# transaction
# translation
# trustar_report
# tsk-chats
# tsk-web-bookmark
# tsk-web-cookie
# tsk-web-downloads
# tsk-web-history
# tsk-web-search-query
# twitter-account
# twitter-list
# twitter-post
# url
# user-account
# vehicle
# victim
# virustotal-graph
# virustotal-report
# vulnerability
# weakness
# whois
# windows-service
# x509
# yabin
# yara
# youtube-channel
# youtube-comment
# youtube-playlist
# youtube-video

# %%
# Look at a specific object format
objectid = 'narrative'

print('Keys: {}\n'.format(objectjsons[objectid].keys()))
print('Attributes: {}\n'.format(objectjsons[objectid]['attributes'].keys()))
objectjsons[objectid]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a6075a28465d> in <module>
#       2 objectid = 'narrative'
#       3
# ----> 4 print('Keys: {}\n'.format(objectjsons[objectid].keys()))
#       5 print('Attributes: {}\n'.format(objectjsons[objectid]['attributes'].keys()))
#       6 objectjsons[objectid]
#
# NameError: name 'objectjsons' is not defined

# %% [markdown]
# # Check standard STIX format also
#
# STIX json is in https://github.com/oasis-open/cti-stix2-json-schemas
